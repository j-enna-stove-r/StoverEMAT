# %% [markdown]
# # Data in Emerging Media and Technology
#
# *What I hope to get out of this class is...*
# 1. _A better understanding of writing data_
# 2. _A better understanding of reading data_
# 3. _To become better at writing in Jupyter_
# 4. _To become more skilled at coding in Python_
# 5. _To understand ethical data practices for research and application_

# %% [markdown]
# ## Systems Check
#
# **I am excited for this class because...**
# - __I want to learn more about Jupyter and Python__
# - __I want to get better at writing and understanding data__
# - __I can further my knowledge of GitHub!__

# %% [markdown]
# ### Jenna Stover
# ![***This is a screenshot from a coding assignment I did last year in my Creative Coding class! I enjoyed doing it and spending time making sure each pumpkin had a different colored face than the others each time I ran the code.***]
# ![Screenshot 2025-08-24 at 03.33.43 1.png](attachment:932178ce-8169-48d7-ab95-84e9ccab1e3d.png)

# %% [markdown]
# #### August 24, 2025

# %%
# Python Syntax EC

x = 3
for i in range(4):
    print ("hi")

def variable_plusone(n):
    return n + 1

print (variable_plusone(x))
# Out:
# hi
# hi
# hi
# hi
# 4
